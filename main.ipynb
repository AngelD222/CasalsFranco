# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/angeld222/CasalsFranco/blob/main/main.ipynb)

# %% [markdown]
# # EML: Práctica 1
#
# ## Introducción
#
# En el presente respositorio se encontrarán desarrolladas los experimentos dedicados a resolver las cuestiones de las partes 1 y 2 de la Práctica 1 de la asignatura de Extensiones de Machine Learning.
#
# ## Estructura del Framework
#
# El proyecto sigue un patrón de diseño orientado a distinguir las dos partes de la práctica:
#
# * **`k_brazos/`**: Desarrollo de la Parte 1: Aprendizaje en el bandido de k-brazos.
#
# * **`entornos_complejos/`**: Desarrollo de la Parte 2: Aprendizaje en entornos complejos.

# %% [markdown]
# ## Configuración del entorno
#
# Para poder ejecutar los diferentes estudios, debemos clonar el repositorio para poder acceder a las diferentes funcionalidades

# %%
# !git clone https://github.com/AngelD222/CasalsFranco.git
# Out:
# Cloning into 'CasalsFranco'...
# remote: Enumerating objects: 825, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 825 (delta 12), reused 6 (delta 4), pack-reused 797 (from 1)
# Receiving objects: 100% (825/825), 6.67 MiB | 17.68 MiB/s, done.
# Resolving deltas: 100% (279/279), done.

# %% [markdown]
# ## Índice de Estudios Realizados
#
# De acuerdo con la estructura del proyecto, se han realizado tres estudios diferenciados según la distribución de probabilidad de los brazos:
#
# 1.  **[Parte 1: Aprendizaje en el bandido de k-brazos.](./k_brazos/main.ipynb)**: Fichero principal para la Parte 1
# 2.  **[Parte 2: Entornos complejos](./entornos_complejos/main.ipynb)**: Fichero principal para la Parte 2.
